# %% [markdown]
# # Ejemplos de uso de pandas
# ### referencias:
# #### https://towardsdatascience.com/30-examples-to-master-pandas-f8a2da751fa4
# #### https://pandas.pydata.org/pandas-docs/dev/user_guide/style.html

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab as pl
from timple.timedelta import strftimedelta
import matplotlib.cbook as cbook
import matplotlib.image as image

import datetime

# %%
data_filename = "./data/mobile_f1_CA.csv"

# %%
results = pd.read_csv(data_filename)
results.iloc[0:10]
# Out:
#     LapTime     S1  S2   S3  Gear    RPM  Velocity
# 0  0:00.078  0.098 NaN  NaN     5  14155       254
# 1  0:00.113  0.098 NaN  NaN     5  14081       255
# 2  0:00.145  0.098 NaN  NaN     5  14114       255
# 3  0:00.178  0.196 NaN  NaN     5  14148       256
# 4  0:00.211  0.196 NaN  NaN     5  14181       257
# 5  0:00.245  0.196 NaN  NaN     5  14214       257
# 6  0:00.278  0.298 NaN  NaN     5  14247       258
# 7  0:00.312  0.298 NaN  NaN     5  14279       258
# 8  0:00.345  0.298 NaN  NaN     5  14312       259
# 9  0:00.378  0.396 NaN  NaN     5  14344       260

# %%
Distance = 4361

# %%
results.head()
# Out:
#     LapTime     S1  S2   S3  Gear    RPM  Velocity
# 0  0:00.078  0.098 NaN  NaN     5  14155       254
# 1  0:00.113  0.098 NaN  NaN     5  14081       255
# 2  0:00.145  0.098 NaN  NaN     5  14114       255
# 3  0:00.178  0.196 NaN  NaN     5  14148       256
# 4  0:00.211  0.196 NaN  NaN     5  14181       257

# %%
results.isna().sum()
# Out:
# LapTime        0
# S1             0
# S2           579
# S3          1254
# Gear           0
# RPM            0
# Velocity       0
# dtype: int64

# %%
results2 = results.query('12000 < RPM < 13000')
results2
# Out:
#        LapTime      S1      S2      S3  Gear    RPM  Velocity
# 48    0:01.678   1.696     NaN     NaN     6  12811       268
# 49    0:01.711   1.696     NaN     NaN     6  12842       268
# 50    0:01.744   1.696     NaN     NaN     6  12870       269
# 51    0:01.778   1.797     NaN     NaN     6  12898       269
# 52    0:01.812   1.797     NaN     NaN     6  12925       270
# ...        ...     ...     ...     ...   ...    ...       ...
# 1994  1:06.546  19.258  22.462  24.729     6  12817       268
# 1995  1:06.580  19.258  22.462  24.829     6  12856       269
# 1996  1:06.612  19.258  22.462  24.829     6  12893       269
# 1997  1:06.646  19.258  22.462  24.829     6  12929       270
# 1998  1:06.679  19.258  22.462  24.928     6  12965       271
#
# [356 rows x 7 columns]

# %%
results['Gear'].plot(kind='hist', figsize=(8,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
results['RPM'].plot(kind='hist', figsize=(8,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
results['Velocity'].plot(kind='hist', figsize=(8,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
results[results['Gear'].isin([3,4,5])][:10]
# Out:
#     LapTime     S1  S2   S3  Gear    RPM  Velocity
# 0  0:00.078  0.098 NaN  NaN     5  14155       254
# 1  0:00.113  0.098 NaN  NaN     5  14081       255
# 2  0:00.145  0.098 NaN  NaN     5  14114       255
# 3  0:00.178  0.196 NaN  NaN     5  14148       256
# 4  0:00.211  0.196 NaN  NaN     5  14181       257
# 5  0:00.245  0.196 NaN  NaN     5  14214       257
# 6  0:00.278  0.298 NaN  NaN     5  14247       258
# 7  0:00.312  0.298 NaN  NaN     5  14279       258
# 8  0:00.345  0.298 NaN  NaN     5  14312       259
# 9  0:00.378  0.396 NaN  NaN     5  14344       260

# %%
results_new = results
results_new.set_index('LapTime')
# Out:
#               S1      S2      S3  Gear    RPM  Velocity
# LapTime
# 0:00.078   0.098     NaN     NaN     5  14155       254
# 0:00.113   0.098     NaN     NaN     5  14081       255
# 0:00.145   0.098     NaN     NaN     5  14114       255
# 0:00.178   0.196     NaN     NaN     5  14148       256
# 0:00.211   0.196     NaN     NaN     5  14181       257
# ...          ...     ...     ...   ...    ...       ...
# 1:07.947  19.258  22.462  26.113     6  14116       295
# 1:07.980  19.258  22.462  26.228     6  14143       295
# 1:08.014  19.258  22.462  26.228     6  14169       296
# 1:08.048  19.258  22.462  26.228     6  14222       297
# 1:08.112  19.258  22.462  26.394     6  14248       298
#
# [2041 rows x 6 columns]

# %%
results.dtypes
# Out:
# LapTime      object
# S1          float64
# S2          float64
# S3           object
# Gear          int64
# RPM           int64
# Velocity      int64
# dtype: object

# %%
pd.to_datetime("12-11-2010 00:00", format="%d-%m-%Y %H:%M")
# Out:
# Timestamp('2010-11-12 00:00:00')
