# %% [markdown]
# ### Predicting Football Results Using Bayesian Modelling with Python and PyMC3
# https://pena.lt/y/2021/08/25/predicting-football-results-using-bayesian-statistics-with-python-and-pymc3/

# %%
import pandas as pd
import numpy as np
from penaltyblog.scrapers import ESPN

# %%
espn = ESPN("ENG Premier League", "2019-2020")

df = espn.get_fixtures()

df.head()
# Out:
#                                                 espn_id  \
# id
# 1565308800---liverpool---norwich_city            541844
# 1565395200---afc_bournemouth---sheffield_united  541840
# 1565395200---burnley---southampton               541841
# 1565395200---crystal_palace---everton            541839
# 1565395200---tottenham_hotspur---aston_villa     541837
#
#                                                                  datetime  \
# id
# 1565308800---liverpool---norwich_city           2019-08-09 19:00:00+00:00
# 1565395200---afc_bournemouth---sheffield_united 2019-08-10 14:00:00+00:00
# 1565395200---burnley---southampton              2019-08-10 14:00:00+00:00
# 1565395200---crystal_palace---everton           2019-08-10 14:00:00+00:00
# 1565395200---tottenham_hotspur---aston_villa    2019-08-10 16:30:00+00:00
#
#                                                  attendance  \
# id
# 1565308800---liverpool---norwich_city                 53333
# 1565395200---afc_bournemouth---sheffield_united       10714
# 1565395200---burnley---southampton                    19784
# 1565395200---crystal_palace---everton                 25151
# 1565395200---tottenham_hotspur---aston_villa          60407
#
#                                                          team_home  \
# id
# 1565308800---liverpool---norwich_city                    Liverpool
# 1565395200---afc_bournemouth---sheffield_united    AFC Bournemouth
# 1565395200---burnley---southampton                         Burnley
# 1565395200---crystal_palace---everton               Crystal Palace
# 1565395200---tottenham_hotspur---aston_villa     Tottenham Hotspur
#
#                                                         team_away  goals_home  \
# id
# 1565308800---liverpool---norwich_city                Norwich City           4
# 1565395200---afc_bournemouth---sheffield_united  Sheffield United           1
# 1565395200---burnley---southampton                    Southampton           3
# 1565395200---crystal_palace---everton                     Everton           0
# 1565395200---tottenham_hotspur---aston_villa          Aston Villa           3
#
#                                                  goals_away appearances_home  \
# id
# 1565308800---liverpool---norwich_city                     1                0
# 1565395200---afc_bournemouth---sheffield_united           1                0
# 1565395200---burnley---southampton                        0                0
# 1565395200---crystal_palace---everton                     0                0
# 1565395200---tottenham_hotspur---aston_villa              1                0
#
#                                                  fouls_committed_home  \
# id
# 1565308800---liverpool---norwich_city                               9
# 1565395200---afc_bournemouth---sheffield_united                    10
# 1565395200---burnley---southampton                                  6
# 1565395200---crystal_palace---everton                              16
# 1565395200---tottenham_hotspur---aston_villa                       13
#
#                                                  won_corners_home  ...  \
# id                                                                 ...
# 1565308800---liverpool---norwich_city                          11  ...
# 1565395200---afc_bournemouth---sheffield_united                 3  ...
# 1565395200---burnley---southampton                              2  ...
# 1565395200---crystal_palace---everton                           6  ...
# 1565395200---tottenham_hotspur---aston_villa                   14  ...
#
#                                                  won_corners_away  \
# id
# 1565308800---liverpool---norwich_city                           2
# 1565395200---afc_bournemouth---sheffield_united                 4
# 1565395200---burnley---southampton                              7
# 1565395200---crystal_palace---everton                           2
# 1565395200---tottenham_hotspur---aston_villa                    0
#
#                                                  goal_assists_away  \
# id
# 1565308800---liverpool---norwich_city                            1
# 1565395200---afc_bournemouth---sheffield_united                  0
# 1565395200---burnley---southampton                               0
# 1565395200---crystal_palace---everton                            0
# 1565395200---tottenham_hotspur---aston_villa                     1
#
#                                                  possession_pct_away  \
# id
# 1565308800---liverpool---norwich_city                           42.1
# 1565395200---afc_bournemouth---sheffield_united                 47.1
# 1565395200---burnley---southampton                              53.5
# 1565395200---crystal_palace---everton                           64.6
# 1565395200---tottenham_hotspur---aston_villa                    29.9
#
#                                                  shot_assists_away  \
# id
# 1565308800---liverpool---norwich_city                           10
# 1565395200---afc_bournemouth---sheffield_united                  5
# 1565395200---burnley---southampton                               5
# 1565395200---crystal_palace---everton                            7
# 1565395200---tottenham_hotspur---aston_villa                     7
#
#                                                  shots_on_target_away  \
# id
# 1565308800---liverpool---norwich_city                               5
# 1565395200---afc_bournemouth---sheffield_united                     3
# 1565395200---burnley---southampton                                  3
# 1565395200---crystal_palace---everton                               3
# 1565395200---tottenham_hotspur---aston_villa                        4
#
#                                                  total_goals_away  \
# id
# 1565308800---liverpool---norwich_city                           1
# 1565395200---afc_bournemouth---sheffield_united                 1
# 1565395200---burnley---southampton                              0
# 1565395200---crystal_palace---everton                           0
# 1565395200---tottenham_hotspur---aston_villa                    1
#
#                                                 total_shots_away     season  \
# id
# 1565308800---liverpool---norwich_city                         12  2019-2020
# 1565395200---afc_bournemouth---sheffield_united                8  2019-2020
# 1565395200---burnley---southampton                            11  2019-2020
# 1565395200---crystal_palace---everton                         10  2019-2020
# 1565395200---tottenham_hotspur---aston_villa                   7  2019-2020
#
#                                                         competition  \
# id
# 1565308800---liverpool---norwich_city            ENG Premier League
# 1565395200---afc_bournemouth---sheffield_united  ENG Premier League
# 1565395200---burnley---southampton               ENG Premier League
# 1565395200---crystal_palace---everton            ENG Premier League
# 1565395200---tottenham_hotspur---aston_villa     ENG Premier League
#
#                                                        date
# id
# 1565308800---liverpool---norwich_city            2019-08-09
# 1565395200---afc_bournemouth---sheffield_united  2019-08-10
# 1565395200---burnley---southampton               2019-08-10
# 1565395200---crystal_palace---everton            2019-08-10
# 1565395200---tottenham_hotspur---aston_villa     2019-08-10
#
# [5 rows x 28 columns]

# %%
df.dtypes
# Out:
# espn_id                              object
# datetime                datetime64[ns, UTC]
# attendance                            int64
# team_home                            object
# team_away                            object
# goals_home                            int64
# goals_away                            int64
# appearances_home                     object
# fouls_committed_home                  int64
# won_corners_home                      int64
# goal_assists_home                     int64
# possession_pct_home                 float64
# shot_assists_home                     int64
# shots_on_target_home                  int64
# total_goals_home                      int64
# total_shots_home                      int64
# appearances_away                     object
# fouls_committed_away                  int64
# won_corners_away                      int64
# goal_assists_away                     int64
# possession_pct_away                 float64
# shot_assists_away                     int64
# shots_on_target_away                  int64
# total_goals_away                      int64
# total_shots_away                      int64
# season                               object
# competition                          object
# date                                 object
# dtype: object

# %%
def log_likelihood(
    goals_home_observed,
    goals_away_observed,
    home_attack,
    home_defence,
    away_attack,
    away_defence,
    home_advantage,
    rho,
    weight
):
    goal_expectation_home = np.exp(home_attack + away_defence + home_advantage)
    goal_expectation_away = np.exp(away_attack + home_defence)

    home_llk = poisson.pmf(goals_home_observed, goal_expectation_home)
    away_llk = poisson.pmf(goals_away_observed, goal_expectation_away)
    adj_llk = rho_correction(
        goals_home_observed,
        goals_away_observed,
        goal_expectation_home,
        goal_expectation_away,
        rho,
    )

    if goal_expectation_home < 0 or goal_expectation_away < 0 or adj_llk < 0:
        return 10000

    log_llk = weight * (np.log(home_llk) + np.log(away_llk) + np.log(adj_llk))

    return -log_llk

# %%
def fit_poisson_model(df, xi=0.0001):
    teams = np.sort(np.unique(np.concatenate([df["team_home"], df["team_away"]])))
    n_teams = len(teams)

    df["days_since"] = (df["datetime"].max() - df["datetime"]).dt.days
    df["weight"] = dc_decay(xi, df["days_since"])

    params = np.concatenate(
        (
            np.random.uniform(0.5, 1.5, (n_teams)),  # attack strength
            np.random.uniform(0, -1, (n_teams)),  # defence strength
            [0.25],  # home advantage
            [-0.1],  # rho
        )
    )

    def _fit(params, df, teams):
        attack_params = dict(zip(teams, params[:n_teams]))
        defence_params = dict(zip(teams, params[n_teams : (2 * n_teams)]))
        home_advantage = params[-2]
        rho = params[-1]

        llk = list()
        for idx, row in df.iterrows():
            tmp = log_likelihood(
                row["fthg"],
                row["ftag"],
                attack_params[row["team_home"]],
                defence_params[row["team_home"]],
                attack_params[row["team_away"]],
                defence_params[row["team_away"]],
                home_advantage,
                rho,
                row["weight"],
            )
            llk.append(tmp)

        return np.sum(llk)

    options = {
        "maxiter": 100,
        "disp": False,
    }

    constraints = [{"type": "eq", "fun": lambda x: sum(x[:n_teams]) - n_teams}]

    res = minimize(
        _fit,
        params,
        args=(df, teams),
        constraints=constraints,
        options=options,
    )

    model_params = dict(
        zip(
            ["attack_" + team for team in teams]
            + ["defence_" + team for team in teams]
            + ["home_adv", "rho"],
            res["x"],
        )
    )

    return model_params

# %%
def predict(params, home_team, away_team):
    home_attack = params["attack_" + home_team]
    home_defence = params["defence_" + home_team]
    away_attack = params["attack_" + away_team]
    away_defence = params["defence_" + away_team]
    home_advantage = params["home_adv"]
    rho = params["rho"]

    home_goal_expectation = np.exp(home_attack + away_defence + home_advantage)
    away_goal_expectation = np.exp(away_attack + home_defence)

    home_probs = poisson.pmf(range(10), home_goal_expectation)
    away_probs = poisson.pmf(range(10), away_goal_expectation)

    m = np.outer(home_probs, away_probs)

    m[0, 0] *= 1 - home_goal_expectation * away_goal_expectation * rho
    m[0, 1] *= 1 + home_goal_expectation * rho
    m[1, 0] *= 1 + away_goal_expectation * rho
    m[1, 1] *= 1 - rho    

    home = np.sum(np.tril(m, -1))
    draw = np.sum(np.diag(m))
    away = np.sum(np.triu(m, 1))

    return home, draw, away

# %%
def calculate_rps(params, df):
    rps = list()
    for idx, row in df.iterrows():
        if row["FTR"] == "H":
            outcome = 0
        elif row["FTR"] == "D":
            outcome = 1
        elif row["FTR"] == "A":
            outcome = 2  

        predictions = predict(params, row["team_home"], row["team_away"])
# ...                                                             ...
# 1595721600---leicester_city---manchester_united  ENG Premier League
# 1595721600---manchester_city---norwich_city      ENG Premier League
# 1595721600---newcastle_united---liverpool        ENG Premier League
# 1595721600---southampton---sheffield_united      ENG Premier League
# 1595721600---west_ham_united---aston_villa       ENG Premier League
#
#                                                        date
# id
# 1565308800---liverpool---norwich_city            2019-08-09
# 1565395200---afc_bournemouth---sheffield_united  2019-08-10
# 1565395200---burnley---southampton               2019-08-10
# 1565395200---crystal_palace---everton            2019-08-10
# 1565395200---tottenham_hotspur---aston_villa     2019-08-10
# ...                                                     ...
# 1595721600---leicester_city---manchester_united  2020-07-26
# 1595721600---manchester_city---norwich_city      2020-07-26
# 1595721600---newcastle_united---liverpool        2020-07-26
# 1595721600---southampton---sheffield_united      2020-07-26
# 1595721600---west_ham_united---aston_villa       2020-07-26
#
# [380 rows x 28 columns]

# %%
train = df.iloc[-380:]
(train["datetime"].max() - train["datetime"]).dt.days
# Out:
# id
# 1565308800---liverpool---norwich_city              351
# 1565395200---afc_bournemouth---sheffield_united    351
# 1565395200---burnley---southampton                 351
# 1565395200---crystal_palace---everton              351
# 1565395200---tottenham_hotspur---aston_villa       350
#                                                   ...
# 1595721600---leicester_city---manchester_united      0
# 1595721600---manchester_city---norwich_city          0
# 1595721600---newcastle_united---liverpool            0
# 1595721600---southampton---sheffield_united          0
# 1595721600---west_ham_united---aston_villa           0
# Name: datetime, Length: 380, dtype: int64

# %%
from pprint import pprint
import numpy as np
from scipy.optimize import minimize
from scipy.stats import poisson

xis = [0, 0.00005, 0.0001, 0.001, 0.0025,]
rps = list()
for xi in xis:
    train = df.iloc[-380:]
    test = df.iloc[-380:]

    train.iloc["days_since"] = (train["datetime"].max() - train["datetime"]).dt.days
    train["weight"] = dc_decay(xi, train["days_since"])

    params = fit_poisson_model(train, xi)
    rps.append(calculate_rps(params, test))

plt.plot(xis, rps)
plt.ticklabel_format(useOffset=False)
plt.xlabel("xi")
plt.ylabel("RPS")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 8>()
#       9 train = df.iloc[-380:]
#      10 test = df.iloc[-380:]
# ---> 12 train.iloc["days_since"] = (train["datetime"].max() - train["datetime"]).dt.days
#      13 train["weight"] = dc_decay(xi, train["days_since"])
#      15 params = fit_poisson_model(train, xi)
#
# File /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages/pandas/core/indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages/pandas/core/indexing.py:1688, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1685 # align and set the values
#    1686 if take_split_path:
#    1687     # We have to operate column-wise
# -> 1688     self._setitem_with_indexer_split_path(indexer, value, name)
#    1689 else:
#    1690     self._setitem_single_block(indexer, value, name)
#
# File /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages/pandas/core/indexing.py:1770, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1767         self._setitem_single_column(ilocs[0], value, pi)
#    1769     else:
# -> 1770         raise ValueError(
#    1771             "Must have equal len keys and value "
#    1772             "when setting with an iterable"
#    1773         )
#    1775 else:
#    1776
#    1777     # scalar value
#    1778     for loc in ilocs:
#
# ValueError: Must have equal len keys and value when setting with an iterable
