# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np
import datetime

try:
    from cryptocmd import CmcScraper
except:
    ! pip install cryptocmd
    from cryptocmd import CmcScraper

    #from cryptocmd import CmcScraper

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
plt.style.use('ggplot')

# Colores Bitcoin
# ==============================================================================
palette_btc = {'naranja': '#f7931a',
               'blanco' : '#ffffff',
               'gris'   : '#4d4d4d',
               'azul'   : '#0d579b',
               'verde'  : '#329239'
              }

# Modelado y Forecasting
# ==============================================================================


    
from skforecast.ForecasterAutoreg import ForecasterAutoreg
from skforecast.model_selection import backtesting_forecaster
#from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# %%
# De ser necesario
#! pip install skforecast
#! pip install lightgbm
# Out:
# Collecting skforecast
#   Downloading skforecast-0.5.1-py2.py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.2/169.2 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting numpy<=1.23,>=1.20
#   Downloading numpy-1.23.0-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 1.3 MB/s eta 0:00:0000:0100:01
# Collecting scikit-optimize==0.9.0
#   Using cached scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
# Collecting seaborn==0.11
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.1/283.1 kB 843.5 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: joblib<=1.2.0,>=1.1.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from skforecast) (1.1.0)
# Collecting statsmodels<=0.13,>=0.12
#   Using cached statsmodels-0.13.0-cp39-cp39-macosx_10_15_x86_64.whl (9.6 MB)
# Collecting pandas<=1.4,>=1.2
#   Using cached pandas-1.4.0-cp39-cp39-macosx_10_9_x86_64.whl (11.5 MB)
# Collecting matplotlib<=3.5,>=3.3
#   Downloading matplotlib-3.5.0-cp39-cp39-macosx_10_9_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 1.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scikit-learn<=1.1,>=1.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from skforecast) (1.0.2)
# Collecting optuna==2.10.0
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.2/308.2 kB 2.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm<=4.64,>=4.57.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from skforecast) (4.64.0)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: scipy!=1.4.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from optuna==2.10.0->skforecast) (1.9.0)
# Collecting cliff
#   Downloading cliff-4.0.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 512.3 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: PyYAML in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from optuna==2.10.0->skforecast) (6.0)
# Collecting alembic
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from optuna==2.10.0->skforecast) (21.3)
# Collecting sqlalchemy>=1.1.0
#   Downloading SQLAlchemy-1.4.42-cp39-cp39-macosx_10_15_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 1.8 MB/s eta 0:00:0000:0100:01m
# Collecting pyaml>=16.9
#   Using cached pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Collecting setuptools-scm>=4
#   Downloading setuptools_scm-7.0.5-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from matplotlib<=3.5,>=3.3->skforecast) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from matplotlib<=3.5,>=3.3->skforecast) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from matplotlib<=3.5,>=3.3->skforecast) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from matplotlib<=3.5,>=3.3->skforecast) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from matplotlib<=3.5,>=3.3->skforecast) (4.34.4)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from matplotlib<=3.5,>=3.3->skforecast) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from pandas<=1.4,>=1.2->skforecast) (2022.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from scikit-learn<=1.1,>=1.0->skforecast) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from statsmodels<=0.13,>=0.12->skforecast) (0.5.2)
# Requirement already satisfied: six in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels<=0.13,>=0.12->skforecast) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from setuptools-scm>=4->matplotlib<=3.5,>=3.3->skforecast) (2.0.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from setuptools-scm>=4->matplotlib<=3.5,>=3.3->skforecast) (61.2.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from setuptools-scm>=4->matplotlib<=3.5,>=3.3->skforecast) (4.3.0)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.0-cp39-cp39-macosx_10_15_x86_64.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting Mako
#   Downloading Mako-1.2.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 1.5 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from cliff->optuna==2.10.0->skforecast) (4.12.0)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.2-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.1/147.1 kB 949.5 kB/s eta 0:00:0000:0100:01
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-4.1.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 1.0 MB/s eta 0:00:00ta 0:00:01
# Collecting PrettyTable>=0.7.2
#   Downloading prettytable-3.5.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=16.3.0 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna==2.10.0->skforecast) (21.4.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna==2.10.0->skforecast) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from importlib-metadata>=4.4->cliff->optuna==2.10.0->skforecast) (3.8.1)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.11.0-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.6/112.6 kB 855.3 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/anaconda3/envs/kerasTensor/lib/python3.9/site-packages (from Mako->alembic->optuna==2.10.0->skforecast) (2.1.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=62397eb183baba19dd802f1cf743a7a7584f6c5f7b4aa2ac4bd7f5b951dd8c7e
#   Stored in directory: /Users/rubenrodriguez/Library/Caches/pip/wheels/0c/09/9e/49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
# Successfully built pyperclip
# Installing collected packages: pyperclip, pyaml, PrettyTable, pbr, numpy, Mako, greenlet, colorlog, cmd2, autopage, stevedore, sqlalchemy, setuptools-scm, pandas, cmaes, statsmodels, matplotlib, cliff, alembic, seaborn, scikit-optimize, optuna, skforecast
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.2
#     Uninstalling numpy-1.23.2:
#       Successfully uninstalled numpy-1.23.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.3
#     Uninstalling pandas-1.4.3:
#       Successfully uninstalled pandas-1.4.3
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.13.2
#     Uninstalling statsmodels-0.13.2:
#       Successfully uninstalled statsmodels-0.13.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.3
#     Uninstalling matplotlib-3.5.3:
#       Successfully uninstalled matplotlib-3.5.3
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.0 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.9.0 which is incompatible.
# Successfully installed Mako-1.2.3 PrettyTable-3.5.0 alembic-1.8.1 autopage-0.5.1 cliff-4.0.0 cmaes-0.8.2 cmd2-2.4.2 colorlog-6.7.0 greenlet-2.0.0 matplotlib-3.5.0 numpy-1.23.0 optuna-2.10.0 pandas-1.4.0 pbr-5.11.0 pyaml-21.10.1 pyperclip-1.8.2 scikit-optimize-0.9.0 seaborn-0.11.0 setuptools-scm-7.0.5 skforecast-0.5.1 sqlalchemy-1.4.42 statsmodels-0.13.0 stevedore-4.1.0
